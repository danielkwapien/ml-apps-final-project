# %%
import pandas as pd

# %%
df = pd.read_csv('./tedscraper/talks.csv')

# %%
df
# Out:
#      talk_id                                              title  \
# 0     129805     How the US is destroying young people's future
# 1     129164                     How to increase your happiness
# 2     127674          Is your partner "the one?" Wrong question
# 3     127527     What is earwax — and should you get rid of it?
# 4     125965                                 How to spot a cult
# ..       ...                                                ...
# 227   103359                    When are you actually an adult?
# 228    99754  Can we feed ourselves without devouring the pl...
# 229   102332  Where does your sense of self come from? A sci...
# 230   101504  A socialist perspective on the pursuit of happ...
# 231   102224                              "Mana" / "Salt Water"
#
#                                            description            speaker  \
# 0    In a scorching talk, marketing professor and p...     Scott Galloway
# ...
