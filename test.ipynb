# %%
import pandas as pd

# %%
df = pd.read_csv('./tedscraper/talks.csv')

# %%
df
# Out:
#     talk_id                                              title  \
# 0    129460    How to govern AI — even if it's hard to predict
# 1    129805     How the US is destroying young people's future
# 2    129164                     How to increase your happiness
# 3    127674          Is your partner "the one?" Wrong question
# 4    127922  Ideas change everything — and what's next for TED
# 5    121120     A new national park to reclaim Indigenous land
# 6    127525   The true story behind the legend of the 47 Rōnin
# 7    127365    Can cannabis help you sleep? Here's the science
# 8    127921             Why you should disappoint your parents
# 9    128545                How to prevent political corruption
# 10   128186  3 strategies to address the teacher shortage c...
# 11   127862             What you can do to stop economic crime
# 12   128548            The Nazis recruited to win the Cold War
# 13   129029         A Palestinian and an Israeli, face to face
# ...
